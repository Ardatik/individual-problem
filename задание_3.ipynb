# %% [markdown]
# Составить уравнение нормали для кривой.
#
# f(x) = x-x^3 x0 = -1
#
# импортируем библиотеки

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Рассмотрим функцию

# %%
def f_x(x: float):
    return x - x ** 3

# %% [markdown]
# Посчитаем производную

# %%
x_0 = -1
dx = 1e-6
dir = (f_x(x_0 + dx/2) - f_x(x_0 - dx/2)) / dx
print(f'"{f_x(x_0)}  {dir}"')
# Out:
# "0  -2.0000000001685336"

# %% [markdown]
# Сформируем точки и уравнение касательной

# %%
x_0 = -1
x = np.linspace(x_0 - 3, x_0 + 3, 200)
y = f_x(x)

m = f_x(x_0) - (dir * x_0)
y_2 = dir * x + m
print(f'Уравнение касательной - "y = {round(m)}"')
# Out:
# Уравнение касательной - "y = -2"

# %% [markdown]
# Построим график

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.grid(True)
ax.plot(x_0, f_x(x_0), color= 'red', marker='*')
ax.plot(x, y, linewidth=1.5, color='black')
ax.plot(x, y_2, linewidth=1, color="blue")
plt.show()
