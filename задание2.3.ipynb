# %% [markdown]
# Вычислить предел функции.

# %% [markdown]
# lim ((x^2 +3 * x + 2)^2 / (x^3+2x^2-x-2) при x → -1

# %% [markdown]
# Импортируем библиотеки

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Рассмотрим функцию.

# %%
def f_x(x):
  y = (x**2 +3 * x + 2)**2 / (x**3+2*x**2-x-2)
  return y

# %% [markdown]
# Обозначим константы и найдем delta и eps.

# %%
delta = 10
dx = 1e-5
eps = 0
x_0 = -1

while delta > dx:
    eps -= 1
    delta = f_x(x_0 - 10 ** eps) - f_x(x_0 + 10 ** eps)
lim = round(f_x(x_0 - 10 ** eps), 3)
print(f'Значение lim - "{lim}"')
# Out:
# Значение lim - "0.0"

# %% [markdown]
# Сформируем точки и построим график.

# %%
x = np.linspace(x_0 - 1, x_0 + 1, 100)
y = f_x(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.grid(True)
ax.plot(x, y, color='black', linewidth=0.5)
ax.scatter(x_0, lim, color='red', marker='*')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
