# %% [markdown]
# Доказать (найти δ(ε) ).
#
# lim (3x^2 + 5x - 2) / (x + 2) = -7 при x → -2
#
# Импортируем библиотеки

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Рассмотрим функцию

# %%
def f_x(x):
    y = (3*x**2 + 5*x - 2) / (x + 2)
    return y

# %% [markdown]
# Обозначим переменные и найдем delta и eps.

# %%
delta = 10
dx = 1e-5
eps = 0
x_0 = -2

while delta > dx:
    eps -= 1
    delta = f_x(x_0 + 10 ** eps) - f_x(x_0 - 10 ** eps)
print(f'Значение delta - "{delta}"\nЗначение eps, при котором delta принимает вид - "{eps}"')
# Out:
# Значение delta - "5.998979091259571e-06"
# Значение eps, при котором delta принимает вид - "-6"

# %% [markdown]
# построим график

# %%
x = np.linspace(x_0 - 0.5, x_0 + 0.5, 100)
y = f_x(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.grid(True)
ax.plot(x, y, color='black', linewidth=0.5)
ax.scatter(x_0, f_x(x_0 + 10 ** eps), color='red', marker='*')
plt.show()
