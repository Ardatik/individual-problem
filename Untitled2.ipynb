# %% [markdown]
# Вычислить lim a_n при n → ∞
#
# a_n = ((n ^ 3 + 1)^1/2 - (n-1) ^ 1/2) / ((n ^ 3 + 1)^1/3 - (n-1) ^ 1/2)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Обозначим переменные и найдем предел

# %%
flag = True
N_eps = 1
eps = 1e-7
delta = 0
x, y = [], []

while flag:
    N_eps = (N_eps + 1)
    an = f_n(N_eps)
    if len(y) > 1:
        delta = abs(y[-1] - an)
    x.append(N_eps)
    y.append(an)
    if (delta > 0) and (delta < eps): flag = False
lim_f = round(y[-1], 2)
print("Предел функции a_n =",lim_f)
# Out:
# Предел функции a_n = 1.5

# %% [markdown]
# Построим график

# %%
fig = plt.figure(10)
ax = fig.add_subplot(1, 1, 1)
ax.grid(True)
ax.scatter(x, y, color='blue', marker='*', linewidth=0.5)
ax.plot(np.linspace(0, len(x)*1.05), np.linspace(lim_f, lim_f), linewidth=1.5, color='red')

plt.show()
